# %% [markdown]
# <a href="https://colab.research.google.com/github/pablex72/computer-vision/blob/main/pillow_computer_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_image = "/content/download.jpg"

import os
cwd = os.getcwd()
cwd
# Out:
# '/content'

# %%
image_path = os.path.join(cwd, my_image)
image_path
# Out:
# '/content/download.jpg'

# %%
from PIL import Image

image = Image.open(my_image)
type(image)

import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.imshow(image)
plt.show()

image = Image.open(image_path)

im = image.load()

# %%
import numpy as np
blue_lenna = Image.open('/content/download.jpg')
blue_array = np.array(blue_lenna)
blue_array[:,:,2] = 0
plt.figure(figsize=(10,10))
plt.imshow(blue_array)
plt.show()
